# %%
import aether_options as ao

ao.fair_value_all(n_sims=1_000_000)
# Out:
#   Fair values  —  S0=50.0, σ=251%, MC paths=1,000,000
#   Product        Kind         Method      Fair       Bid       Ask   Edge(buy)  Edge(sell)
#   --------------------------------------------------------------------------------
#   AC             underlying   MC       50.0181   49.9750   50.0250     -0.0069     -0.0431
#   AC_50_P        put          BS       12.0269   12.0000   12.0500     -0.0231     -0.0269
#   AC_50_C        call         BS       12.0269   12.0000   12.0500     -0.0231     -0.0269
#   AC_35_P        put          BS        4.3361    4.3300    4.3500     -0.0139     -0.0061
#   AC_40_P        put          BS        6.5095    6.5000    6.5500     -0.0405     -0.0095
#   AC_45_P        put          BS        9.0889    9.0500    9.1000     -0.0111     -0.0389
#   AC_60_C        call         BS        8.7918    8.8000    8.8500     -0.0582     +0.0082
#   AC_50_P_2      put          BS        9.8707    9.7000    9.7500     +0.1207     -0.1707
# ...

# %%
positions = {'AC': 0, 'AC_50_P': 0, 'AC_50_C': 0, 'AC_35_P': 0, 'AC_45_P': 0, 'AC_60_C': 0, 'AC_50_P_2': 50, 'AC_50_C_2': 50, 'AC_50_CO': -50, 'AC_40_BP': -50, 'AC_45_KO': 500}
results = ao.run(positions, n_outer_sims=10_000)

# %%
results.summary()
# Out:
# ----------------------------------------------------------
#   Aether Crystal strategy — Monte Carlo summary
#   S0=50.0  σ=251%  inner=100 paths  outer=10,000 trials
#   (Each 'trial' = avg PnL across 100 sims, matching platform scoring)
# ----------------------------------------------------------
#   Expected score (EV)                 +169,420.26
#   Std dev of score (SD)                345,858.03
#   Sharpe (EV/SD)                           0.4899
#   P(score > 0)                             68.8%
# ----------------------------------------------------------
#   Score percentiles:
#        1th       -643,287.25
#        5th       -401,978.83
#       10th       -275,912.52
#       25th        -62,474.89
#       50th       +171,611.29
#       75th       +400,705.42
#       90th       +607,237.97
#       95th       +727,961.20
#       99th       +979,002.02
# ----------------------------------------------------------
#   Per-product EV breakdown:
# ...
