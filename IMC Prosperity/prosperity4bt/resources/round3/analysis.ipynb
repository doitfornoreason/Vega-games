# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels as sm

def fa(n,m, a, b):
    f,a = plt.subplots(n,m, figsize = (a,b))
    return f,a

# %%
prices = pd.concat([pd.read_csv(f"prices_round_3_day_{i}.csv", delimiter = ';') for i in [0, 1, 2]])
trades = pd.concat([pd.read_csv(f"trades_round_3_day_{i}.csv", delimiter = ';') for i in [0, 1, 2]])
prices = {product: prices[prices['product'] == product] for product in prices['product'].unique()}
hp, ve = prices['HYDROGEL_PACK'], prices['VELVETFRUIT_EXTRACT']

# %%
hp.head()
# Out:
#     day  timestamp        product  bid_price_1  bid_volume_1  bid_price_2  \
# 7     0          0  HYDROGEL_PACK         9992            15       9990.0
# 19    0        100  HYDROGEL_PACK         9992            13       9990.0
# 24    0        200  HYDROGEL_PACK         9995            13       9992.0
# 41    0        300  HYDROGEL_PACK         9994            11       9992.0
# 54    0        400  HYDROGEL_PACK         9995            13       9993.0
#
#     bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 7           30.0          NaN           NaN        10008            15
# 19          30.0          NaN           NaN        10008            13
# 24          21.0          NaN           NaN        10011            13
# 41          23.0          NaN           NaN        10010            11
# 54          23.0          NaN           NaN        10011            13
#
#     ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
f,a = fa(2,1, 10, 5)
sns.lineplot( [hp['bid_price_1'], hp['ask_price_1']], ax = a[0], palette = 'pastel')
sns.lineplot( [ve['bid_price_1'], ve['ask_price_1']], ax = a[1], palette = 'pastel')
